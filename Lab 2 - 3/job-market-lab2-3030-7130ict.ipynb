# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
df = pd.read_csv('job-market.csv')
df
# Out:
#                Id                                              Title  \
# 0      37404348.0                           Casual Stock Replenisher
# 1      37404337.0                           Casual Stock Replenisher
# 2      37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3      37404330.0                              Team member - Belrose
# 4      37404308.0  Business Banking Contact Centre Specialist, Ni...
# ...           ...                                                ...
# 40784         NaN                                                NaN
# 40785         NaN                                                NaN
# 40786         NaN                                                NaN
# 40787         NaN                                                NaN
# 40788         NaN                                                NaN
#
#                                               Company  \
# 0                                         Aldi Stores
# ...

# %%
# %matplotlib inline


sns.set(rc={'figure.figsize':(11.10,15.40)})
ax = sns.countplot(y='Location', data=df)
plt.show()

# %%
#create dataframe for salary ranges
df = pd.read_csv('job-market.csv')

# %%
#salary ranges plot
fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 15))
df.groupby(['LowestSalary']).count().plot(kind='pie', y='Title', textprops={'fontsize': 14}, ax=ax1)
ax1.set_ylabel('Salary Range', size=22)
plt.show()

# %%
#OPTIONAL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('job-market.csv')

locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf_location = locationDf['Location']
locationDf['Count'] = locationDf["Id"]

locationDf = locationDf['Count']
locationDf_location
# Out:
# Location
# ACT                                                                    ACT
# Adelaide                                                          Adelaide
# Adelaide Hills & Barossa                          Adelaide Hills & Barossa
# Albany & Great Southern                            Albany & Great Southern
# Albury Area                                                    Albury Area
#                                                       ...
# Western QLD                                                    Western QLD
# Whyalla & Eyre Peninsula                          Whyalla & Eyre Peninsula
# Wollongong, Illawarra & South Coast    Wollongong, Illawarra & South Coast
# Yarra Valley & High Country                    Yarra Valley & High Country
# Yorke Peninsula & Clare Valley              Yorke Peninsula & Clare Valley
# Name: Location, Length: 65, dtype: object

# %%
#optional
# %matplotlib inline

from matplotlib import cm

fig, ax = plt.subplots(figsize=(10, 15))
ax.pie(locationDf[0:6], labels = locationDf_location[0:6])

plt.show()
